# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %%
! mongoimport --type json -d uk_food -c establishments --drop --jsonArray ./Resources/establishments.json
# Out:
# 2024-05-18T20:56:16.678-0400	connected to: mongodb://localhost/
# 2024-05-18T20:56:16.679-0400	dropping: uk_food.establishments
# 2024-05-18T20:56:19.682-0400	[##############..........] uk_food.establishments	23.1MB/39.3MB (58.6%)
# 2024-05-18T20:56:21.698-0400	[########################] uk_food.establishments	39.3MB/39.3MB (100.0%)
# 2024-05-18T20:56:21.698-0400	39779 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names()
      )
# Out:
# ['admin', 'autosaurus', 'config', 'epa', 'local', 'met', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names()
      )
# Out:
# ['establishments']

# %%
# review the collections in our new database
print(db.list_collection_names()
      )
# Out:
# ['establishments']

# %%
# assign the collection to a variable
# establishments = db['establishments']
establishments = db.establishments

# %%
establishments.find_one()       # to Check that there is data loaded into the database
# Out:
# {'_id': ObjectId('66494e3037a2c2886846fad6'),
#  'FHRSID': 551803,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000070948',
#  'BusinessName': 'The Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'The Pines Garden',
#  'AddressLine2': 'Beach Road',
#  'AddressLine3': 'St Margarets Bay',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT15 6DZ',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2021-08-17T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.383298', 'latitude': '51.148133'},
#  'RightToReply': '',
#  'Distance': 4587.362402580997,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
# ...

# %%
establishments.count_documents({})
# Out:
# 39779

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant ={
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
    
}

# %%
establishments.find_one({"BusinessName":"Penang Flavours", "PostCode":"SE18 7DY"})       # checks to see if there is an existing document with this information

# %%
query_new_rest = {"BusinessName":"Penang Flavours", "PostCode":"SE18 7DY"}
results = establishments.find(query_new_rest)
for restaurant in results:
    pprint(restaurant)

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('66494e961d7dab8a35f19e1a'), acknowledged=True)

# %%
establishments.count_documents({})
# Out:
# 39780

# %%
# Check that the new restaurant was inserted
establishments.find_one({"BusinessName":"Penang Flavours", "PostCode":"SE18 7DY"})
# Out:
# {'_id': ObjectId('66494e961d7dab8a35f19e1a'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %%
query_new_rest_after_insert = {"BusinessName":"Penang Flavours", "PostCode":"SE18 7DY"}
results = establishments.find(query_new_rest_after_insert)
for restaurant in results:
    pprint(restaurant)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66494e961d7dab8a35f19e1a'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType": "Restaurant/Cafe/Canteen"}
field = {"BusinessTypeID":1,"BusinessType":1}

results = list(establishments.find(query, field))

# list(establishments.find_one(query, field))
pprint(results)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('66494e3037a2c2886846fad6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('66494e3037a2c2886846fad7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('66494e3037a2c2886846fad9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('66494e3037a2c2886846fada')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('66494e3037a2c2886846fadb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('66494e3037a2c2886846fadc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('66494e3037a2c2886846fadd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('66494e3037a2c2886846fae3')},
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
    new_restaurant, 
    {"$set": 
    {"BusinessTypeID": 1}
    }
    )
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
establishments.find_one({"BusinessName":"Penang Flavours", "PostCode":"SE18 7DY"})
# Out:
# {'_id': ObjectId('66494e961d7dab8a35f19e1a'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
establishments.count_documents({})
# Out:
# 39780

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({"LocalAuthorityName": "Dover"})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({"LocalAuthorityName": "Dover"})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
establishments.count_documents({"LocalAuthorityName": "Dover"})
# Out:
# 0

# %%
establishments.count_documents({})
# Out:
# 38786

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('66494e3037a2c2886846fdbc'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{"$set":
                                 {"geocode.longitude":{"$toDecimal":"$geocode.longitude"},
                                 "geocode.latitude":{"$toDecimal":"$geocode.latitude"}
                                 }
                                }
                               ]
                          )
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{"$set":
                                 {"RatingValue": {"$toInt":"$RatingValue"}
                                 }
                                }
                               ]
                          )
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
list(establishments.aggregate([{
    "$project":
    {"longitude":{"$isNumber":"$geocode.longitude"},
     "latitude": {"$isNumber": "$geocode.latitude"}
}}]))
# Out:
# [{'_id': ObjectId('66494e3037a2c2886846fdbc'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdbd'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdbe'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc1'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc2'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc4'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc5'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc6'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc7'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc8'),
#   'longitude': True,
#   'latitude': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc9'),
# ...

# %%
list(establishments.aggregate([{
    "$project":
    {"RatingValue":{"$isNumber":"$RatingValue"}
}}]))
# Out:
# [{'_id': ObjectId('66494e3037a2c2886846fdbc'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdbd'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdbe'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc1'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc2'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc4'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc5'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc6'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc7'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc8'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdc9'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdca'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdcb'), 'RatingValue': True},
#  {'_id': ObjectId('66494e3037a2c2886846fdcc'), 'RatingValue': True},
# ...
